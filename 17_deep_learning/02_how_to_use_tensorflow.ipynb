# %% [markdown]
# # How to use Tensorflow 2

# %% [markdown]
# Keras was designed as a high-level or meta API to accelerate the iterative workflow when designing and training deep neural networks with computational backends like TensorFlow, Theano, or CNTK. It has been integrated into TensorFlow in 2017 and is set to become the principal TensorFlow interface with the 2.0 release. You can also combine code from both libraries to leverage Keras’ high-level abstractions as well as customized TensorFlow graph operations.

# %% [markdown]
# Please follow the installations instructions in `Installation Guide.md` in the root folder.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

from pathlib import Path
from copy import deepcopy
import numpy as np
import pandas as pd

import sklearn
from sklearn.datasets import make_circles # To generate the dataset

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import TensorBoard

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D  # 3D plots

import seaborn as sns

# %%
# plotting style
sns.set_style('white')
# for reproducibility
np.random.seed(seed=42)

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using CPU

# %%
results_path = Path('results')
if not results_path.exists():
    results_path.mkdir()

# %% [markdown]
# ## Input Data

# %% [markdown]
# ### Generate random data

# %% [markdown]
# The target `y` represents two classes generated by two circular distribution that are not linearly separable because class 0 surrounds class 1.

# %%
# dataset params
N = 50000
factor = 0.1
noise = 0.1

# %%
# generate data
X, y = make_circles(
    n_samples=N,
    shuffle=True,
    factor=factor,
    noise=noise)

# %%
# define outcome matrix
Y = np.zeros((N, 2))
for c in [0, 1]:
    Y[y == c, c] = 1

# %%
f'Shape of: X: {X.shape} | Y: {Y.shape} | y: {y.shape}'
# Out:
# 'Shape of: X: (50000, 2) | Y: (50000, 2) | y: (50000,)'

# %% [markdown]
# ### Visualize Data

# %%
sns.scatterplot(x=X[:, 0], 
                y=X[:, 1], 
                hue=y,
               style=y,
               markers=['_', '+']);

# %% [markdown]
# ## Build Keras Model

# %% [markdown]
# Keras supports both a slightly simpler Sequential and more flexible Functional API. We will introduce the former at this point and use the Functional API in more complex examples in the following chapters.
#
# To create a model, we just need to instantiate a Sequential object and provide a list with the sequence of standard layers and their configurations, including the number of units, type of activation function, or name.

# %% [markdown]
# ### Define Architecture

# %%
model = Sequential([
    Dense(units=3, input_shape=(2,), name='hidden'),
    Activation('sigmoid', name='logistic'),
    Dense(2, name='output'),
    Activation('softmax', name='softmax'),
])

# %% [markdown]
# The first hidden layer needs information about the number of features in the matrix it receives from the input layer via the input_shape argument. In our simple case, these are just two. Keras infers the number of rows it needs to process during training, through the batch_size argument that we will pass to the fit method below.
#
# Keras infers the sizes of the inputs received by other layers from the previous layer’s units argument.

# %% [markdown]
# Keras provides numerous standard building blocks, including recurrent and convolutional layers, various options for regularization, a range of loss functions and optimizers, and also preprocessing, visualization and logging (see documentation on GitHub for reference). It is also extensible.
#
# The model’s summary method produces a concise description of the network architecture, including a list of the layer types and shapes, and the number of parameters:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 3)                 9
#
#  logistic (Activation)       (None, 3)                 0
#
#  output (Dense)              (None, 2)                 8
#
#  softmax (Activation)        (None, 2)                 0
#
# =================================================================
# Total params: 17 (68.00 Byte)
# Trainable params: 17 (68.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Compile Model

# %% [markdown]
# Next, we compile the Sequential model to configure the learning process. To this end, we define the optimizer, the loss function, and one or several performance metrics to monitor during training:

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Tensorboard Callback

# %% [markdown]
# Keras uses callbacks to enable certain functionality during training, such as logging information for interactive display in TensorBoard (see next section):

# %%
tb_callback = TensorBoard(log_dir=results_path / 'tensorboard', 
                          histogram_freq=1, 
                          write_graph=True, 
                          write_images=True)

# %% [markdown]
# ## Train Model

# %% [markdown]
# To train the model, we call its fit method and pass several parameters in addition to the training data:

# %%
training=model.fit(X, 
          Y, 
          epochs=50,
          validation_split=.2,
          batch_size=128, 
          verbose=1, 
          callbacks=[tb_callback])
# Out:
# Epoch 1/50
# 313/313 [==============================] - 3s 5ms/step - loss: 0.7051 - accuracy: 0.5838 - val_loss: 0.6951 - val_accuracy: 0.6954
# Epoch 2/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6934 - accuracy: 0.6277 - val_loss: 0.6932 - val_accuracy: 0.6372
# Epoch 3/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6921 - accuracy: 0.5879 - val_loss: 0.6915 - val_accuracy: 0.5911
# Epoch 4/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6898 - accuracy: 0.5482 - val_loss: 0.6883 - val_accuracy: 0.6546
# Epoch 5/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6850 - accuracy: 0.6018 - val_loss: 0.6811 - val_accuracy: 0.5952
# Epoch 6/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6751 - accuracy: 0.6531 - val_loss: 0.6680 - val_accuracy: 0.7138
# Epoch 7/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6586 - accuracy: 0.7934 - val_loss: 0.6478 - val_accuracy: 0.8465
# Epoch 8/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6358 - accuracy: 0.8543 - val_loss: 0.6217 - val_accuracy: 0.8649
# Epoch 9/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6079 - accuracy: 0.8623 - val_loss: 0.5917 - val_accuracy: 0.8715
# Epoch 10/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5770 - accuracy: 0.8667 - val_loss: 0.5595 - val_accuracy: 0.8665
# Epoch 11/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5447 - accuracy: 0.8669 - val_loss: 0.5267 - val_accuracy: 0.8734
# Epoch 12/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5125 - accuracy: 0.8704 - val_loss: 0.4942 - val_accuracy: 0.8774
# Epoch 13/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4810 - accuracy: 0.8748 - val_loss: 0.4629 - val_accuracy: 0.8774
# Epoch 14/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4502 - accuracy: 0.8788 - val_loss: 0.4323 - val_accuracy: 0.8820
# Epoch 15/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4203 - accuracy: 0.8840 - val_loss: 0.4027 - val_accuracy: 0.8889
# Epoch 16/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3910 - accuracy: 0.8890 - val_loss: 0.3738 - val_accuracy: 0.8942
# Epoch 17/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3624 - accuracy: 0.8946 - val_loss: 0.3454 - val_accuracy: 0.8989
# Epoch 18/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3341 - accuracy: 0.9003 - val_loss: 0.3174 - val_accuracy: 0.9043
# Epoch 19/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3059 - accuracy: 0.9074 - val_loss: 0.2892 - val_accuracy: 0.9121
# Epoch 20/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2775 - accuracy: 0.9136 - val_loss: 0.2609 - val_accuracy: 0.9188
# Epoch 21/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2489 - accuracy: 0.9234 - val_loss: 0.2325 - val_accuracy: 0.9302
# Epoch 22/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2212 - accuracy: 0.9376 - val_loss: 0.2059 - val_accuracy: 0.9447
# Epoch 23/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1951 - accuracy: 0.9492 - val_loss: 0.1810 - val_accuracy: 0.9555
# Epoch 24/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1713 - accuracy: 0.9603 - val_loss: 0.1586 - val_accuracy: 0.9709
# Epoch 25/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1497 - accuracy: 0.9841 - val_loss: 0.1382 - val_accuracy: 0.9952
# Epoch 26/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1303 - accuracy: 0.9966 - val_loss: 0.1201 - val_accuracy: 0.9992
# Epoch 27/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1130 - accuracy: 0.9992 - val_loss: 0.1038 - val_accuracy: 0.9995
# Epoch 28/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0976 - accuracy: 0.9995 - val_loss: 0.0897 - val_accuracy: 0.9999
# Epoch 29/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0842 - accuracy: 0.9997 - val_loss: 0.0773 - val_accuracy: 0.9999
# Epoch 30/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0725 - accuracy: 0.9997 - val_loss: 0.0665 - val_accuracy: 0.9999
# Epoch 31/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0624 - accuracy: 0.9998 - val_loss: 0.0572 - val_accuracy: 0.9999
# Epoch 32/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0536 - accuracy: 0.9998 - val_loss: 0.0491 - val_accuracy: 0.9999
# Epoch 33/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0460 - accuracy: 0.9999 - val_loss: 0.0422 - val_accuracy: 0.9999
# Epoch 34/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0396 - accuracy: 0.9999 - val_loss: 0.0364 - val_accuracy: 0.9999
# Epoch 35/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0342 - accuracy: 0.9999 - val_loss: 0.0314 - val_accuracy: 0.9999
# Epoch 36/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0295 - accuracy: 0.9999 - val_loss: 0.0271 - val_accuracy: 0.9999
# Epoch 37/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0256 - accuracy: 0.9999 - val_loss: 0.0235 - val_accuracy: 0.9999
# Epoch 38/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0222 - accuracy: 0.9999 - val_loss: 0.0204 - val_accuracy: 0.9999
# Epoch 39/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0193 - accuracy: 0.9999 - val_loss: 0.0178 - val_accuracy: 0.9999
# Epoch 40/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0169 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9999
# Epoch 41/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0148 - accuracy: 0.9999 - val_loss: 0.0137 - val_accuracy: 0.9999
# Epoch 42/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0130 - accuracy: 0.9999 - val_loss: 0.0120 - val_accuracy: 0.9999
# Epoch 43/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0115 - accuracy: 0.9999 - val_loss: 0.0106 - val_accuracy: 0.9999
# Epoch 44/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0102 - accuracy: 0.9999 - val_loss: 0.0094 - val_accuracy: 0.9999
# Epoch 45/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0090 - accuracy: 0.9999 - val_loss: 0.0084 - val_accuracy: 0.9999
# Epoch 46/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0081 - accuracy: 0.9999 - val_loss: 0.0075 - val_accuracy: 0.9999
# Epoch 47/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0072 - accuracy: 0.9999 - val_loss: 0.0067 - val_accuracy: 0.9999
# Epoch 48/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0065 - accuracy: 0.9999 - val_loss: 0.0061 - val_accuracy: 0.9999
# Epoch 49/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0059 - accuracy: 0.9999 - val_loss: 0.0055 - val_accuracy: 0.9999
# Epoch 50/50
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0050 - val_accuracy: 0.9999

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14,4))
pd.DataFrame(training.history)[['accuracy', 'val_accuracy']].plot(ax=axes[0])
pd.DataFrame(training.history)[['loss', 'val_loss']].plot(ax=axes[1])
sns.despine()
fig.tight_layout();

# %% [markdown]
# ## Get Weights

# %%
hidden = model.get_layer('hidden').get_weights()

# %%
[t.shape for t in hidden]
# Out:
# [(2, 3), (3,)]

# %% [markdown]
# ## Plot Decision Boundary

# %% [markdown]
# The visualization of the decision boundary resembles the result from the manual network implementation. The training with Keras runs a multiple faster, though.

# %%
n_vals = 200
x1 = np.linspace(-1.5, 1.5, num=n_vals)
x2 = np.linspace(-1.5, 1.5, num=n_vals)
xx, yy = np.meshgrid(x1, x2)  # create the grid

# %%
X_ = np.array([xx.ravel(), yy.ravel()]).T

# %%
y_hat = np.argmax(model.predict(X_), axis=1)
# Out:
# 1250/1250 [==============================] - 2s 2ms/step

# %%
# Create a color map to show the classification colors of each grid point
cmap = ListedColormap([sns.xkcd_rgb["pale red"],
                       sns.xkcd_rgb["denim blue"]])

# Plot the classification plane with decision boundary and input samples
plt.contourf(xx, yy, y_hat.reshape(n_vals, -1), cmap=cmap, alpha=.25)

# Plot both classes on the x1, x2 plane
data = pd.DataFrame(X, columns=['$x_1$', '$x_2$']).assign(Class=pd.Series(y).map({0:'negative', 1:'positive'}))
sns.scatterplot(x='$x_1$', y='$x_2$', hue='Class', data=data, style=y, markers=['_', '+'], legend=False)
sns.despine()
plt.title('Decision Boundary');

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir results/tensorboard/
# Out:
#       <iframe id="tensorboard-frame-af1cfd25b91a194" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-af1cfd25b91a194");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
